# %% [markdown]
# ## General setup

# %% [markdown]
# importing libraries

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import numpy as np
import json
from geopy.geocoders import Nominatim
from bs4 import BeautifulSoup
from urllib.request import urlopen
import requests
from pandas.io.json import json_normalize
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
import folium
import wikipedia as wp

# %% [markdown]
# I will be scraping the table from Wikipedia, the first goal is to get the table with postal codes of boroughs of Toronto

# %%
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
page = urlopen(url).read().decode('utf-8')
soup = BeautifulSoup(page, 'html.parser')
wiki_table = soup.body.table.tbody

# %%
tor = pd.read_html(url, header = 0)[0]
tor = df[tor.Borough != 'Not assigned']  #ignoring blank boroughs
tor = tor.groupby(['Postcode', 'Borough'])['Neighbourhood'].apply(list).apply(lambda x:', '.join(x)).to_frame().reset_index() #joins postcodes with more than one neighborhood

for index, row in tor.iterrows():
    if row['Neighbourhood'] == 'Not assigned':
        row['Neighbourhood'] = row['Borough']  #if the neighborhood is blank, it will be the same as borough

tor
# Out:
# c:\users\barborapencikova\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#    Postcode           Borough  \
# 0       M1E       Scarborough
# 1       M1G       Scarborough
# 2       M1H       Scarborough
# 3       M1J       Scarborough
# 4       M1K       Scarborough
# 5       M1L       Scarborough
# 6       M1M       Scarborough
# 7       M1P       Scarborough
# 8       M1R       Scarborough
# 9       M1S       Scarborough
# 10      M1V       Scarborough
# 11      M1W       Scarborough
# 12      M1X       Scarborough
# 13      M2H        North York
# 14      M2J        North York
# 15      M2K        North York
# 16      M2N        North York
# 17      M2P        North York
# 18      M2R        North York
# 19      M3A        North York
# 20      M3B        North York
# 21      M3C        North York
# 22      M3H        North York
# 23      M3J        North York
# 24      M3L        North York
# 25      M3M        North York
# 26      M3N        North York
# 27      M4A        North York
# 28      M4B         East York
# 29      M4G         East York
# 30      M4H         East York
# 31      M4J         East York
# 32      M4K      East Toronto
# 33      M4L      East Toronto
# 34      M4M      East Toronto
# 35      M4N   Central Toronto
# 36      M4S   Central Toronto
# 37      M4T   Central Toronto
# 38      M4V   Central Toronto
# 39      M5A  Downtown Toronto
# 40      M5E  Downtown Toronto
# 41      M5G  Downtown Toronto
# 42      M5H  Downtown Toronto
# 43      M5M        North York
# 44      M5N   Central Toronto
# 45      M5P   Central Toronto
# 46      M5R   Central Toronto
# 47      M5S  Downtown Toronto
# 48      M5T  Downtown Toronto
# 49      M5V  Downtown Toronto
# 50      M5W  Downtown Toronto
# 51      M5X  Downtown Toronto
# 52      M6A        North York
# 53      M6B        North York
# 54      M6H      West Toronto
# 55      M6J      West Toronto
# 56      M6K      West Toronto
# 57      M6L        North York
# 58      M6M              York
# 59      M6N              York
# 60      M6P      West Toronto
# 61      M6R      West Toronto
# 62      M6S      West Toronto
# 63      M7A      Queen's Park
# 64      M7R       Mississauga
# 65      M7Y      East Toronto
# 66      M8Y         Etobicoke
# 67      M8Z         Etobicoke
# 68      M9A         Etobicoke
# 69      M9B         Etobicoke
# 70      M9C         Etobicoke
# 71      M9L        North York
# 72      M9M        North York
# 73      M9N              York
# 74      M9P         Etobicoke
# 75      M9R         Etobicoke
# 76      M9V         Etobicoke
# 77      M9W         Etobicoke
#
#                                         Neighbourhood
# 0                   Guildwood, Morningside, West Hill
# 1                                              Woburn
# 2                                           Cedarbrae
# 3                                 Scarborough Village
# 4         East Birchmount Park, Ionview, Kennedy Park
# 5                     Clairlea, Golden Mile, Oakridge
# 6     Cliffcrest, Cliffside, Scarborough Village West
# 7   Dorset Park, Scarborough Town Centre, Wexford ...
# 8                                   Maryvale, Wexford
# 9                                           Agincourt
# 10  Agincourt North, L'Amoreaux East, Milliken, St...
# 11                                    L'Amoreaux West
# 12                                        Upper Rouge
# 13                                  Hillcrest Village
# 14                       Fairview, Henry Farm, Oriole
# 15                                    Bayview Village
# 16                                   Willowdale South
# 17                                    York Mills West
# 18                                    Willowdale West
# 19                                          Parkwoods
# 20                                    Don Mills North
# 21                   Flemingdon Park, Don Mills South
# 22    Bathurst Manor, Downsview North, Wilson Heights
# 23                    Northwood Park, York University
# 24                                     Downsview West
# 25                                  Downsview Central
# 26                                Downsview Northwest
# 27                                   Victoria Village
# 28                    Woodbine Gardens, Parkview Hill
# 29                                            Leaside
# 30                                   Thorncliffe Park
# 31                                       East Toronto
# 32                       The Danforth West, Riverdale
# 33                     The Beaches West, India Bazaar
# 34                                    Studio District
# 35                                      Lawrence Park
# 36                                         Davisville
# 37                        Moore Park, Summerhill East
# 38  Deer Park, Forest Hill SE, Rathnelly, South Hi...
# 39                          Harbourfront, Regent Park
# 40                                        Berczy Park
# 41                                 Central Bay Street
# 42                           Adelaide, King, Richmond
# 43                  Bedford Park, Lawrence Manor East
# 44                                           Roselawn
# 45                Forest Hill North, Forest Hill West
# 46                The Annex, North Midtown, Yorkville
# 47                     Harbord, University of Toronto
# 48          Chinatown, Grange Park, Kensington Market
# 49  CN Tower, Bathurst Quay, Island airport, Harbo...
# 50                    Stn A PO Boxes 25 The Esplanade
# 51             First Canadian Place, Underground city
# 52                   Lawrence Heights, Lawrence Manor
# 53                                          Glencairn
# 54                       Dovercourt Village, Dufferin
# 55                           Little Portugal, Trinity
# 56       Brockton, Exhibition Place, Parkdale Village
# 57                 Downsview, North Park, Upwood Park
# 58     Del Ray, Keelesdale, Mount Dennis, Silverthorn
# 59                      The Junction North, Runnymede
# 60                      High Park, The Junction South
# 61                             Parkdale, Roncesvalles
# 62                                 Runnymede, Swansea
# 63                                       Queen's Park
# 64              Canada Post Gateway Processing Centre
# 65  Business Reply Mail Processing Centre 969 Eastern
# 66  Humber Bay, King's Mill Park, Kingsway Park So...
# 67  Kingsway Park South West, Mimico NW, The Queen...
# 68                                   Islington Avenue
# 69  Cloverdale, Islington, Martin Grove, Princess ...
# 70  Bloordale Gardens, Eringate, Markland Wood, Ol...
# 71                                      Humber Summit
# 72                                   Emery, Humberlea
# 73                                             Weston
# 74                                          Westmount
# 75  Kingsview Village, Martin Grove Gardens, Richv...
# 76  Albion Gardens, Beaumond Heights, Humbergate, ...
# 77                                          Northwest

# %% [markdown]
# # shape of the dataframe:

# %%
tor.shape
# Out:
# (78, 3)
